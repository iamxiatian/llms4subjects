# %% [markdown]
# # Test

# %%
import os
from pprint import pprint

os.chdir("/root/xiatian/github/llms4subjects")

# %%
from llms4subjects.subject import subject_db_all

subject_db_all.alias['Dokumentensuchsystem']
# Out:
# 'gnd:4670557-0'

# %%
from llms4subjects.parse import parse_jsonld

test_file = "./test_core/Article/en/3A72999578X.jsonld"
test_file = "./data/shared-task-datasets/TIBKAT/merged-subjects/data/train/Article/en/3A1831630516.jsonld"
d = parse_jsonld(test_file)
print(d)
# Out:
# {'abstract': 'About 10% of the US labor force is employed in selling related '
#              'occupations and the expenditures on selling activities total '
#              'close to 5% of the US GDP. Without question, selling occupies a '
#              'prominent role in our economy. This chapter offers a discussion '
#              'on the construct of selling, its role in economic models, and '
#              'the various aspects of firm decisions that relate to it.',
#  'doctype': 'Article',
#  'gnd_codes': [{'@id': 'http://d-nb.info/gnd/4037589-4'}],
#  'id': '3A1831630516',
#  'language': 'en',
#  'title': 'Chapter 8. Selling and sales management'}

# %%
from llms4subjects.subject import subject_eq

names = [
            "Koordinierung",
            "information retrieval",
            "Topoloy",]

for name in names:
    namecodes = subject_eq.get_namecodes_by_name(name, 5)
    print(f"{name} => ")
    for n, c in namecodes:
        print(f'    {n} -- {c}')
# Out:
# Koordinierung =>
#     Koordinatisierung -- gnd:4762308-1
#     Koordination -- gnd:4206611-6
#     Forschungskoordination -- gnd:4195349-6
#     Koordination -- gnd:4032393-6
#     Kollineation -- gnd:4164692-7
# information retrieval =>
#     Information-Retrieval-System -- gnd:4670557-0
#     Information Retrieval -- gnd:4072803-1
#     Visual Information Retrieval -- gnd:1036714454
#     Online-Recherche -- gnd:4115449-6
#     Information Extraction -- gnd:4566641-6
# Topoloy =>
#     tofet -- gnd:1162073098
#     Topoisomerasen -- gnd:4367246-2
#     Tonplastik -- gnd:4185691-0
#     Tölpel -- gnd:7755840-6
#     topos -- gnd:1148983899

# %%
from pathlib import Path
import os

json_files = list(Path("./db/test_result_core").glob("**/*.json"))

# %%
import json

n_less50 = 0
for json_file in json_files:
    with open(json_file, "r", encoding="utf-8") as f:
        data = json.load(f)
        codes = data['dcterms:subject']
        n_codes = len(codes)
        if n_codes != 50:
            n_less50 += 1
            #print(f"{n_less50}\t{n_codes}\t{json_file}")
            
print(f"total: {n_less50}")
# Out:
# 'total: 51'

# %%
from llms4subjects.subject import subject_db_all

codes = [  "gnd:4059827-5",
    "gnd:4078260-8",
    "gnd:4045959-7",
    "gnd:4014692-3",
    "gnd:4064211-2",
    "gnd:4165441-9",
    "gnd:4013384-9",
    "gnd:4194658-3",]
for c in codes:
    name = subject_db_all.get_name_by_code(c)
    print(name)
# Out:
# 'Thermodynamik'
# 'Thermochemie'
# 'Physikalische Chemie'
# 'Energie'
# 'Wärmeübertragung'
# 'Kraftfahrzeugtechnik'
# 'Dynamik'
# 'Thermodynamisches Gleichgewicht'

# %%
import json
from llms4subjects.parse import parse_jsonld

test_file = "./data/test_all/Book/de/3A127963340.jsonld"
d = parse_jsonld(test_file)
pprint(d)

with open("./db/test_result_all/Book/de/3A127963340.json", "r") as f:
    data = json.load(f)
    
codes = data["dcterms:subject"]

print("new result:")
for c in codes:
    print("\t", subject_db_all.get_name_by_code(c))
    
    
print("================")
print("old result:")
with open("./db/temp/test/Book/de/3A127963340.json", "r") as f:
    data = json.load(f)
    
codes = data["dcterms:subject"]

for c in codes:
    print("\t", subject_db_all.get_name_by_code(c))
# Out:
# {'abstract': 'Auf diese "Lebenswelt" der Geisteswissenschaften mit ihrer '
#              'strukturierenden und regulierenden Kraft lenkt der Sammelband '
#              'die Aufmerksamkeit. Er untersucht am Beispiel der '
#              'germanistischen Literaturwissenschaft die Einbindung des Fachs '
#              'in das System der "Geisteswissenschaften" und zeichnet '
#              'exemplarisch den Wandel literaturwissenschaftlicher '
#              'Darstellungs- und Arbeitsformen in Geschichte und Gegenwart '
#              'nach. Die Beiträge zeigen damit, daß die Arbeit des "Geistes" '
#              'auch gesteuert wird von tradierten wie modernen '
#              'Institutionalisierungsformen der "Wissenschaft" und daß das '
#              '"Geld" eine größere, wenn auch noch schwer greifbare Rolle zu '
#              'spielen beginnt. - Eine ausführliche Bibliographie rundet den '
#              'Band ab. Gliederung: I. Literaturwissenschaft als '
#              'Geisteswissenschaft (u. a. Das Verschwinden des Eigensinns - '
#              'Strukturwandel - Unterscheidung von Natur- und '
#              'Geisteswissenschaften) II. Darstellungsformen in der '
#              'Literaturwissenschaft (Monographie, Schreiben von '
#              'Literaturgeschichte, Lehrbücher, Geschichtliche Interpretation, '
#              'Probleme wissenschaftlicher Edition, Forschung und '
#              'Bibliographie, Rezensionswesen) III. Arbeits- und '
#              'Organisationsformen in der Literaturwissenschaft '
#              '(Literaturwissenschaftliche Gesellschaften, Habilitation als '
#              'Sozialisation, Gutachten und Bewertungssystem, Konstallationen '
#              'kooperativer Forschung) Anhang: Bibliographie zur Theorie- und '
#              'Wissenschaftsgeschichte der Geisteswissenschaften - Verzeichnis '
#              'der Mitarbeiter - Register: Begriffe - Namen (PHF/teilw. übern.)',
#  'doctype': 'Book',
#  'gnd_codes': None,
#  'id': '3A127963340',
#  'language': 'de',
#  'title': 'Geist, Geld und Wissenschaft : Arbeits- und Darstellungsformen von '
#           'Literaturwissenschaft'}
# new result:
# 	 Religion
# 	 Interdisziplinarität
# 	 Lesen
# 	 Religion
# 	 Kultur
# 	 Krise
# 	 Soziale Konstruktion
# 	 Bildung
# 	 Wirtschaft
# 	 Empirische Forschung
# 	 Narrativität
# 	 Raum
# 	 Politische Ökonomie
# 	 Musik
# 	 Zahlungsmittel
# 	 Geschlechterverhältnis
# 	 Geschlecht
# 	 Form
# 	 Kapitalmarkt
# 	 Gesellschaft
# 	 Lehre
# 	 Faustdichtung
# 	 Arabistik
# 	 Ausbildung
# 	 Finanzwissenschaft
# 	 Interpretation
# 	 Wissenschaft
# 	 Literarischer Nachlass
# 	 Künstlerbuch
# 	 Literaturwissenschaft
# 	 Literatur
# 	 Geisteswissenschaften
# 	 Literaturtheorie
# 	 Wissenschaftssoziologie
# 	 Germanistik
# 	 Wissenschaft
# 	 Geld
# 	 Literarische Form
# 	 Literatursoziologie
# 	 Wissenssoziologie
# 	 Literaturunterricht
# 	 Geschichtswissenschaft
# 	 Deutsch
# 	 Digital Humanities
# 	 Wissenschaftsgeschichtsschreibung
# 	 Literarisches Museum
# 	 Kulturwissenschaften
# 	 Geschichtsunterricht
# 	 Forschung
# 	 Krise
# ================
# old result:
# 	 Literaturwissenschaft
# 	 Literatur
# 	 Geisteswissenschaften
# 	 Germanistik
# 	 Geld
# 	 Wissenschaft
# 	 Deutsch
# 	 Digital Humanities
# 	 Wissenschaft
# 	 Kulturwissenschaften
# 	 Religion
# 	 Forschung
# 	 Krise
# 	 Digitalisierung
# 	 Methode
# 	 Interdisziplinarität
# 	 Form
# 	 Literarische Form
# 	 Englisch
# 	 Religionswissenschaft
# 	 Wissenschaftliches Arbeiten
# 	 Zukunft
# 	 Literaturtheorie
# 	 Lesen
# 	 Geschichtswissenschaft
# 	 Leseforschung
# 	 Religion
# 	 Geschlechterforschung
# 	 Arbeitstechnik
# 	 Ästhetik
# 	 Geschichte
# 	 Kulturgeschichtsschreibung
# 	 Raum
# 	 Kreditwesen
# 	 Kultur
# 	 Soziologie
# 	 Universität
# 	 Wirtschaft
# 	 Quantitative Literaturwissenschaft
# 	 Globalisierung
# 	 Sozialwissenschaften
# 	 Wissenschaftsforschung
# 	 Schreiben
# 	 Lehrbuch
# 	 Wissenschaftssoziologie
# 	 Psychologie
# 	 Neue Medien
# 	 Begriff
# 	 Buch
# 	 Wirtschaft

# %%
import json
from llms4subjects.parse import parse_jsonld

test_file = "./data/test_all/Book/de/3A127963340.jsonld"
d = parse_jsonld(test_file)
pprint(d)

with open("./db/test_result_all/Book/de/3A127963340.json", "r") as f:
    data = json.load(f)
    
codes = data["dcterms:subject"]

print("new result:")
for c in codes:
    print("\t", subject_db_all.get_name_by_code(c))
    
    
print("================")
print("old result:")
with open("./db/temp/test/Book/de/3A127963340.json", "r") as f:
    data = json.load(f)
    
codes = data["dcterms:subject"]

for c in codes:
    print("\t", subject_db_all.get_name_by_code(c))
# Out:
# {'abstract': 'Auf diese "Lebenswelt" der Geisteswissenschaften mit ihrer '
#              'strukturierenden und regulierenden Kraft lenkt der Sammelband '
#              'die Aufmerksamkeit. Er untersucht am Beispiel der '
#              'germanistischen Literaturwissenschaft die Einbindung des Fachs '
#              'in das System der "Geisteswissenschaften" und zeichnet '
#              'exemplarisch den Wandel literaturwissenschaftlicher '
#              'Darstellungs- und Arbeitsformen in Geschichte und Gegenwart '
#              'nach. Die Beiträge zeigen damit, daß die Arbeit des "Geistes" '
#              'auch gesteuert wird von tradierten wie modernen '
#              'Institutionalisierungsformen der "Wissenschaft" und daß das '
#              '"Geld" eine größere, wenn auch noch schwer greifbare Rolle zu '
#              'spielen beginnt. - Eine ausführliche Bibliographie rundet den '
#              'Band ab. Gliederung: I. Literaturwissenschaft als '
#              'Geisteswissenschaft (u. a. Das Verschwinden des Eigensinns - '
#              'Strukturwandel - Unterscheidung von Natur- und '
#              'Geisteswissenschaften) II. Darstellungsformen in der '
#              'Literaturwissenschaft (Monographie, Schreiben von '
#              'Literaturgeschichte, Lehrbücher, Geschichtliche Interpretation, '
#              'Probleme wissenschaftlicher Edition, Forschung und '
#              'Bibliographie, Rezensionswesen) III. Arbeits- und '
#              'Organisationsformen in der Literaturwissenschaft '
#              '(Literaturwissenschaftliche Gesellschaften, Habilitation als '
#              'Sozialisation, Gutachten und Bewertungssystem, Konstallationen '
#              'kooperativer Forschung) Anhang: Bibliographie zur Theorie- und '
#              'Wissenschaftsgeschichte der Geisteswissenschaften - Verzeichnis '
#              'der Mitarbeiter - Register: Begriffe - Namen (PHF/teilw. übern.)',
#  'doctype': 'Book',
#  'gnd_codes': None,
#  'id': '3A127963340',
#  'language': 'de',
#  'title': 'Geist, Geld und Wissenschaft : Arbeits- und Darstellungsformen von '
#           'Literaturwissenschaft'}
# new result:
# 	 Literaturwissenschaft
# 	 Literatur
# 	 Germanistik
# 	 Geisteswissenschaften
# 	 Geld
# 	 Religion
# 	 Literarische Form
# 	 Deutsch
# 	 Digital Humanities
# 	 Religion
# 	 Kulturwissenschaften
# 	 Krise
# 	 Digitalisierung
# 	 Krise
# 	 Methode
# 	 Interdisziplinarität
# 	 Englisch
# 	 Religionswissenschaft
# 	 Wissenschaftliches Arbeiten
# 	 Zukunft
# 	 Literaturtheorie
# 	 Lesen
# 	 Geschichtswissenschaft
# 	 Leseforschung
# 	 Geschlechterforschung
# 	 Arbeitstechnik
# 	 Ästhetik
# 	 Kulturgeschichtsschreibung
# 	 Raum
# 	 Kreditwesen
# 	 Kultur
# 	 Soziologie
# 	 Universität
# 	 Wirtschaft
# 	 Quantitative Literaturwissenschaft
# 	 Globalisierung
# 	 Sozialwissenschaften
# 	 Wissenschaftsforschung
# 	 Lehrbuch
# 	 Wissenschaftssoziologie
# 	 Forschung
# 	 Psychologie
# 	 Neue Medien
# 	 Buch
# 	 Wirtschaft
# 	 Entstehung
# 	 Bibliothek
# 	 Narrativität
# 	 Geheimwissenschaft
# 	 Humanwissenschaften
# ================
# old result:
# 	 Literaturwissenschaft
# 	 Literatur
# 	 Geisteswissenschaften
# 	 Germanistik
# 	 Geld
# 	 Wissenschaft
# 	 Deutsch
# 	 Digital Humanities
# 	 Wissenschaft
# 	 Kulturwissenschaften
# 	 Religion
# 	 Forschung
# 	 Krise
# 	 Digitalisierung
# 	 Methode
# 	 Interdisziplinarität
# 	 Form
# 	 Literarische Form
# 	 Englisch
# 	 Religionswissenschaft
# 	 Wissenschaftliches Arbeiten
# 	 Zukunft
# 	 Literaturtheorie
# 	 Lesen
# 	 Geschichtswissenschaft
# 	 Leseforschung
# 	 Religion
# 	 Geschlechterforschung
# 	 Arbeitstechnik
# 	 Ästhetik
# 	 Geschichte
# 	 Kulturgeschichtsschreibung
# 	 Raum
# 	 Kreditwesen
# 	 Kultur
# 	 Soziologie
# 	 Universität
# 	 Wirtschaft
# 	 Quantitative Literaturwissenschaft
# 	 Globalisierung
# 	 Sozialwissenschaften
# 	 Wissenschaftsforschung
# 	 Schreiben
# 	 Lehrbuch
# 	 Wissenschaftssoziologie
# 	 Psychologie
# 	 Neue Medien
# 	 Begriff
# 	 Buch
# 	 Wirtschaft

# %%
llm_file = "/root/xiatian/github/llms4subjects/db/temp/Classification/Article/en/3A1743761929.txt"
